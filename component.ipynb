# %%
from pyunicorn.timeseries.surrogates import Surrogates
import pyunicorn
import numpy as np
from scipy.stats import norm
from netCDF4 import Dataset
import random
import csv
import PCA_functions as pf
import pandas as pd
from Data import Data
from datetime import datetime
import math
import pandas as pd

# %%
class Surrogates:

    """
    Encapsulates structures and methods related to surrogate time series.
    Provides data structures and methods to generate surrogate data sets from a
    set of time series and to evaluate the significance of various correlation
    measures using these surrogates.
    More information on time series surrogates can be found in [Schreiber2000]_
    and [Kantz2006]_.
    """

    #
    #  Define internal methods
    #
    def __init__(self, original_data, silence_level=1):
        """
        Initialize an instance of Surrogates.
        .. note::
           The order of array dimensions is different from the standard of
           ``core``. Here it is [index, time] for reasons of computational
           speed!
        :type original_data: 2D array [index, time]
        :arg original_data: The original time series for surrogate generation.
        :arg int silence_level: The inverse level of verbosity of the object.
        """
        if silence_level <= 1:
            print("Generated an instance of the Surrogates class.")

        #  Set class variables
        self.original_data = original_data
        """The original time series for surrogate generation."""
        self.silence_level = silence_level
        """(string) - The inverse level of verbosity of the object."""

        #  Set flags
        self._normalized = False
        self._fft_cached = False
        self._twins_cached = False

        #  Cache
        self._twins = None
        self._original_data_fft = None
        
        

    def clear_cache(self):
        """Clean up cache."""
        try:
            del self._original_data_fft
            del self._twins
        except AttributeError:
            pass
    def correlated_noise_surrogates(self, original_data):
        """
        Return Fourier surrogates.
        Generate surrogates by Fourier transforming the :attr:`original_data`
        time series (assumed to be real valued), randomizing the phases and
        then applying an inverse Fourier transform. Correlated noise surrogates
        share their power spectrum and autocorrelation function with the
        original_data time series.
        The Fast Fourier transforms of all time series are cached to facilitate
        a faster generation of several surrogates for each time series. Hence,
        :meth:`clear_cache` has to be called before generating surrogates from
        a different set of time series!
        .. note::
           The amplitudes are not adjusted here, i.e., the
           individual amplitude distributions are not conserved!
        **Examples:**
        The power spectrum is conserved up to small numerical deviations:
        >>> ts = Surrogates.SmallTestData().original_data
        >>> surrogates = Surrogates.\
                SmallTestData().correlated_noise_surrogates(ts)
        >>> all(r(np.abs(np.fft.fft(ts,         axis=1))[0,1:10]) == \
                r(np.abs(np.fft.fft(surrogates, axis=1))[0,1:10]))
        True
        However, the time series amplitude distributions differ:
        >>> all(np.histogram(ts[0,:])[0] == np.histogram(surrogates[0,:])[0])
        False
        :type original_data: 2D array [index, time]
        :arg original_data: The original time series.
        :rtype: 2D array [index, time]
        :return: The surrogate time series.
        """
        if self.silence_level <= 1:
            print("Generating correlated noise surrogates...")

        #  Calculate FFT of original_data time series
        #  The FFT of the original_data data has to be calculated only once,
        #  so it is stored in self._original_data_fft.
        if self._fft_cached:
            surrogates = self._original_data_fft
        else:
            surrogates = np.fft.rfft(original_data, axis=1)
            self._original_data_fft = surrogates
            self._fft_cached = True

        #  Get shapes
        (N, n_time) = original_data.shape
        len_phase = surrogates.shape[1]

        #  Generate random phases uniformly distributed in the
        #  interval [0, 2*Pi]
        phases = np.random.uniform(low=0, high=2 * np.pi, size=(N, len_phase))

        #  Add random phases uniformly distributed in the interval [0, 2*Pi]
        surrogates *= np.exp(1j * phases)

        #  Calculate IFFT and take the real part, the remaining imaginary part
        #  is due to numerical errors.
        return np.ascontiguousarray(np.real(np.fft.irfft(surrogates, n=n_time,
                                                         axis=1)))

# %%
def deseasonalize(data,freq=12):
    """
    The shape of data should be (time, index) 
    """
    n  = data.shape[1]
    N  = data.shape[0]
    data_deseasonal = np.zeros(data.shape)
    for i in range(n):
        temp = np.copy(data[:,i])
        r = np.zeros((N))
        for j in range(freq):
            Idx = np.arange(j,N,freq)
            if temp[Idx].std() == 0:
                r[Idx] = 0
            else:
                r[Idx] = (temp[Idx] - temp[Idx].mean())/temp[Idx].std()
        data_deseasonal[:,i] = np.copy(r)
    return(data_deseasonal)

# %%
level = 12
temporal_limits = {"time_min":datetime(1948, 1, 1, 0, 0),"time_max":datetime(2016, 1, 1, 0, 0) }

# %%
sst = Data('../nc/sst.mnmean.nc','sst',temporal_limits, missing_value= -9.96921e+36)

result = sst.get_data()
lon_sst_list = sst.get_lon_list()
lat_sst_list = sst.get_lat_list()
lon_sst = sst.get_lon()
lat_sst = sst.get_lat()

data = deseasonalize(np.array(result))
weights = np.sqrt(np.abs(np.cos(np.array(lat_sst_list)* math.pi/180)))
for i in range(len(weights)):
    data[:,i] = weights[i] * data[:,i]

# %%
d = Data('../nc/sst.mnmean.nc','sst',temporal_limits, missing_value= -9.96921e+36)

result = d.get_data()
lon_list = d.get_lon_list()
lat_list = d.get_lat_list()
lon = d.get_lon()
lat = d.get_lat()

result = deseasonalize(np.array(result))
data = np.transpose(result)
weights = np.sqrt(np.abs(np.cos(np.array(lat_list)* math.pi/180)))

for i in range(len(weights)):
    data[i,:] = weights[i] * data[i,:]

p_value = 0.05/data.shape[0]

# %%
data.shape
# Out:
# (10988, 817)

# %%
eigenValues, eigenVectors = np.linalg.eig(np.cov(data))
idx = eigenValues.argsort()[::-1]
eigenValues = eigenValues[idx]

# %%
result.shape[0]
# Out:
# 356

# %%
result.iloc[:,0].values.mean()
# Out:
# 565.4282440271938

# %%
result = pd.read_csv("limitTemp_sst.csv")

# %%
result.iloc[1,:].values.mean()
# Out:
# 0.6760628857148552

# %%
data1.shape[0]
# Out:
# 356

# %%
    N = 200
    M = data.shape[0]
    result = np.zeros((N,M))
    for i in range(N):
        ts = Surrogates(data)
        sample = ts.correlated_noise_surrogates(data)
        eigenValues, eigenVectors = np.linalg.eig(np.cov(sample))
        idx = eigenValues.argsort()[::-1]
        eigenValues = eigenValues[idx]
        result[i,:] = eigenValues
        ts.clear_cache()
        with open('limitTemp_sst.csv','a') as f:
            writer = csv.writer(f)
            writer.writerow(result[i,:])



    limit = np.zeros(N)
    for i in range(N):
        #limit[i] = 1 - norm.cdf((eigenValues[i] - result[i,:].mean())/result[i,:].std())
        limit[i] = 1 - norm.cdf((eigenValues[i] - result[:,i].mean())/(result[:,i].std()/math.sqrt(N)))
        if limit[i] > p_value: break

    f = open("limit_sst.txt", "a")
    f.write("{} is {}\n".format(name[j], i))

# %%
data = np.load('data.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-582ae71e7b21> in <module>()
# ----> 1 data = np.load('data.npy')
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.npy'

# %%
data = np.load('spi12.npy')

# %%
f_pre = Dataset('../nc/precipitation.nc')
data = f_pre.variables['precip']
lon = f_pre.variables['lon'][:]
lat = f_pre.variables['lat'][:]
time = f_pre.variables['time'][:]
data = np.swapaxes(data,0,2)

# %%
result = []

for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        if not data[i,j,-1]<0:
        #if not np.isnan(data[i,j,-1]):   
            result.append(data[i,j,11:])

# %%
result = pf.deseasonalize(np.transpose(np.array(result)))

# %%
data = np.matrix(result)
data = np.transpose(data)

# %%
f_pre = Dataset('GPCC_half.nc')
data = f_pre.variables['precip']
data = np.swapaxes(data,0,2)

#data = np.load('data.npy')

result = []

for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        if not data[i,j,-1]<0:
        #if not np.isnan(data[i,j,-1]):   
            result.append(data[i,j,:])


result = pf.deseasonalize(np.transpose(np.array(result)))
data = np.matrix(result)
data = np.transpose(data)

# %%
result = pd.read_csv("limitTemp_half.csv")

# %%
result = np.matrix(result)

# %%
result.shape
# Out:
# (129, 13434)

# %%
level = 12
temporal_limits = {"time_min":datetime(1948, 1, 1, 0, 0),"time_max":datetime(2016, 1, 1, 0, 0) }

# %%
name = ["precipitation.nc","pres.mon.mean.nc","precipitation.nc"]
id = ["precip", "pres", "precip"]
missing = [-9.969209968386869e+36, -9.969209968386869e+36, -9.969209968386869e+36]

# %%
for j in range(len(name)):
    d = Data('../nc/{}'.format(name[j]),code[j],temporal_limits,missing_value=missing[j])

    result = d.get_data()
    lon_list = d.get_lon_list()
    lat_list = d.get_lat_list()
    lon = d.get_lon()
    lat = d.get_lat()
    
    result = pf.deseasonalize(np.array(result))
    data = np.transpose(result)
    weights = np.sqrt(np.cos(np.array(lat_list)* math.pi/180))

    for i in range(len(weights)):
        data[i,:] = weights[i] * data[i,:]
        
    N = 20
    M = data.shape[0]
    result = np.zeros((N,M))

    for i in range(N):
        ts = Surrogates(data)
        #sample = ts.correlated_noise_surrogates(data)
        sample = ts.refined_AAFT_surrogates(data, n_iterations=100)

        eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(sample))
        idx = eigenValues.argsort()[::-1]   
        eigenValues = eigenValues[idx]
        result[i,:] = eigenValues
        ts.clear_cache()
        
    eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(data))
    idx = eigenValues.argsort()[::-1]   
    eigenValues = eigenValues[idx]
    
    limit = np.zeros(M)
    for i in range(M):
        limit[i] = 1 - norm.cdf((eigenValues[i] - result[:,i].mean())/result[:,i].std())
        if limit[i] > p_value: break
    f = open("limit.txt", "a")
    f.write("{} is {}\n".format(name[j], i))
    f.close()
# Out:
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...

# %% [markdown]
# # Number of Components os SPI

# %%
level = 12
temporal_limits = {"time_min":datetime(1946, 1, 1, 0, 0),"time_max":datetime(2016, 1, 1, 0, 0) }
spatial_limits = {"lon_min":-40,"lon_max":60,"lat_min":-40,"lat_max":40}

# %%
d = Data('../nc/precip.mon.total.2.5x2.5.v2018.nc','precip',temporal_limits,missing_value=-9.96921e+36)

result = d.get_data()
lon_list = d.get_lon_list()
lat_list = d.get_lat_list()
lon = d.get_lon()
lat = d.get_lat()

# %%
result = np.load("World_gamma.npy")
result = result[:-1,:]
index = np.where(np.isinf(result))
result[index] = -2

# %%
result.shape
# Out:
# (468, 3638)

# %%
np.save("World_gamma.npy",result)

# %%
result = np.load("World_gamma.npy")
data = np.transpose(result[:-1,:])
index = np.where(np.isinf(data))
data[index] = -2.3263478740408408

# %%
weights = np.sqrt(np.abs(np.cos(np.array(lat_list)* math.pi/180)))

# %%
for i in range(len(weights)):
    data[i,:] = weights[i] * data[i,:]

# %%
eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(data))
idx = eigenValues.argsort()[::-1]   
eigenValues = eigenValues[idx]

# %%
np.count_nonzero(eigenValues > (1+math.sqrt(data.shape[0]/data.shape[1]))**2)
# Out:
# 46

# %%
d = Data('../nc/sst.mnmean.nc','sst',temporal_limits,missing_value=-9.96921e+36)

result = d.get_data()
lon_list = d.get_lon_list()
lat_list = d.get_lat_list()
lon = d.get_lon()
lat = d.get_lat()

# %%
result  = result[:,3:]

# %%
c = np.corrcoef(np.transpose(result))
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
c.shape
# Out:
# (10988, 10988)

# %%
np.count_nonzero(np.isnan(c))
# Out:
# 5038275

# %%
c = np.nan_to_num(c)

# %%
c
# Out:
# array([[ 1.        ,  0.29036095,  0.13682917, ..., -0.04993022,
#         -0.04357997, -0.03129445],
#        [ 0.29036095,  1.        ,  0.5300719 , ..., -0.26086539,
#         -0.22697259, -0.15930152],
#        [ 0.13682917,  0.5300719 ,  1.        , ..., -0.58991362,
#         -0.52411689, -0.40143879],
#        ...,
#        [-0.04993022, -0.26086539, -0.58991362, ...,  1.        ,
#          0.96663335,  0.78364142],
#        [-0.04357997, -0.22697259, -0.52411689, ...,  0.96663335,
#          1.        ,  0.82862391],
#        [-0.03129445, -0.15930152, -0.40143879, ...,  0.78364142,
#          0.82862391,  1.        ]])

# %%
result = np.transpose(result)

# %%
lat_list[0]
# Out:
# 88.0

# %%
result  = result[3:,:]

# %%
lat_list = lat_list[3:]

# %%
lon_list = lon_list[3:]

# %%
data.shape
# Out:
# (10988, 817)

# %%
result = pf.deseasonalize(np.array(result))

# %%
data = np.transpose(result)

# %%
weights = np.sqrt(np.abs(np.cos(np.array(lat_list)* math.pi/180)))

for i in range(len(weights)):
    data[i,:] = weights[i] * data[i,:]

# %%
(1+math.sqrt(data.shape[0]/data.shape[1]))**2
# Out:
# 3.540451048526307

# %%
eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(data))
idx = eigenValues.argsort()[::-1]   
eigenValues = eigenValues[idx]

# %%
np.count_nonzero(eigenValues > (1+math.sqrt(data.shape[0]/data.shape[1]))**2)
# Out:
# 39

# %%
N = 20
M = data.shape[0]
result = np.zeros((N,M))

for i in range(N):
    ts = Surrogates(data)
    sample = ts.correlated_noise_surrogates(data)
    #sample = ts.AAFT_surrogates(data)
    
    eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(sample))
    idx = eigenValues.argsort()[::-1]   
    eigenValues = eigenValues[idx]
    result[i,:] = eigenValues
    ts.clear_cache()
    #with open('limit.csv','a') as f:
     #   writer = csv.writer(f)
      #  writer.writerow(result[i,:])
# Out:
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...

# %%
eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(data))
idx = eigenValues.argsort()[::-1]   
eigenValues = eigenValues[idx]

# %%
p_value = 0.05/data.shape[0]

# %%
p_value
# Out:
# 7.874015748031497e-05

# %%
limit = np.zeros(M)
for i in range(M):
    limit[i] = 1 - norm.cdf((eigenValues[i] - result[:,i].mean())/(result[:,i].std()/math.sqrt(N)))
    #print("%f"%(1 - norm.cdf((eigenValues[i] - result[:,i].mean())/result[:,i].std())))
    if limit[i] > p_value: break

# %%
i
# Out:
# 59

# %%
from numpy import random

# %%
random.ra

# %%
#from pyunicorn.pyunicorn.timeseries.surrogates import Surrogates
import numpy as np
from scipy.stats import norm
from netCDF4 import Dataset
import random
import csv
#import PCA_functions as pf
import pandas as pd
from Data import Data
from datetime import datetime
import math

def deseasonalize(data,freq=12):
    """
    The shape of data should be (time, index) 
    """
    n  = data.shape[1]
    N  = data.shape[0]
    data_deseasonal = np.zeros(data.shape)
    for i in range(n):
        temp = np.copy(data[:,i])
        r = np.zeros((N))
        for j in range(freq):
            Idx = np.arange(j,N,freq)
            if temp[Idx].std() == 0:
                r[Idx] = 0
            else:
                r[Idx] = (temp[Idx] - temp[Idx].mean())/temp[Idx].std()
        data_deseasonal[:,i] = np.copy(r)
    return(data_deseasonal)


level = 12
temporal_limits = {"time_min":datetime(1948, 1, 1, 0, 0),"time_max":datetime(2016, 1, 1, 0, 0) }

name = ["precip.mon.total.2.5x2.5.v2018.nc","pres.mon.mean.nc","air.mon.mean.nc","sst.mnmean.nc"]
code = ["precip", "pres", "air", "sst"]
missing = [-9.96921e+36, -9.96921e+36, -9.96921e+36,-9.96921e+36]

for j in range(len(name)):
    d = Data('{}'.format(name[j]),code[j],temporal_limits,missing_value=missing[j])
    
    result = d.get_data()

    result = deseasonalize(np.array(result))
    data = np.transpose(result)
    weights = np.sqrt(np.cos(np.array(lat_list)* math.pi/180))

    eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(data))
    idx = eigenValues.argsort()[::-1]   
    eigenValues = eigenValues[idx]

    number = np.count_nonzero(eigenValues > (1+math.sqrt(data.shape[0]/data.shape[1]))**2)

    f = open("number.txt", "a")
    f.write("{} is {}\n".format(name[j], number))
    f.close()

# %%
#from pyunicorn.pyunicorn.timeseries.surrogates import Surrogates
import numpy as np
from scipy.stats import norm
from netCDF4 import Dataset
import random
import csv
#import PCA_functions as pf
import pandas as pd
from Data import Data
from datetime import datetime
import math

def deseasonalize(data,freq=12):
    """
    The shape of data should be (time, index) 
    """
    n  = data.shape[1]
    N  = data.shape[0]
    data_deseasonal = np.zeros(data.shape)
    for i in range(n):
        temp = np.copy(data[:,i])
        r = np.zeros((N))
        for j in range(freq):
            Idx = np.arange(j,N,freq)
            if temp[Idx].std() == 0:
                r[Idx] = 0
            else:
                r[Idx] = (temp[Idx] - temp[Idx].mean())/temp[Idx].std()
        data_deseasonal[:,i] = np.copy(r)
    return(data_deseasonal)

# %%
level = 12
temporal_limits = {"time_min":datetime(1948, 1, 1, 0, 0),"time_max":datetime(2016, 1, 1, 0, 0) }

name = "../nc/sst.mnmean.nc"
code =  "sst"
missing = -9.96921e+36

# %%
d = Data('{}'.format(name),code,temporal_limits,missing_value=missing)

result = d.get_data()
lon_list = d.get_lon_list()
lat_list = d.get_lat_list()
lon = d.get_lon()
lat = d.get_lat()

# %%
result = pf.deseasonalize(np.array(result))
data = np.transpose(result)
#weights = np.sqrt(np.cos(np.array(lat_list)* math.pi/180))
weights = np.sqrt(np.abs(np.cos(np.array(lat_list)* math.pi/180)))

# %%
for i in range(len(weights)):
    data[i,:] = weights[i] * data[i,:]

# %%
data.shape
# Out:
# (10988, 817)

# %%
c = np.corrcoef(data)
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
c.shape
# Out:
# (10988, 10988)

# %%
np.count_nonzero(np.isnan(c))
# Out:
# 8270119

# %%
    eigenValues, eigenVectors = np.linalg.eig(np.corrcoef(data))
    idx = eigenValues.argsort()[::-1]
    eigenValues = eigenValues[idx]

    number = np.count_nonzero(eigenValues > (1+math.sqrt(data.shape[0]/data.shape[1]))**2)

    f = open("number.txt", "a")
    f.write("{} is {}\n".format(name[j], number))

# %%
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
c
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ..., 1.        , 0.73245799,
#         0.21527619],
#        [       nan,        nan,        nan, ..., 0.73245799, 1.        ,
#         0.22548907],
#        [       nan,        nan,        nan, ..., 0.21527619, 0.22548907,
#         1.        ]])

# %%
data.shape
# Out:
# (635, 817)

# %%
limit = np.load("limit.npy")

# %%
for i in range(M):
    if limit[i]<0.05 and limit[i+1]>0.05:
        print("%f"%(i))
        break
# Out:
# 58.000000

# %%
for i in range(2000):
    print("%f"%(limit[i]))
# Out:
# 0.000000
# 0.000000
# 0.000000
# 0.000080
# 0.013419
# 0.027787
# 0.048526
# 0.103424
# 0.135305
# 0.172163
# 0.178612
# 0.199780
# 0.221764
# 0.229446
# 0.237565
# 0.245592
# 0.253328
# 0.258030
# 0.269907
# 0.281925
# 0.286005
# 0.289908
# 0.295204
# 0.298934
# 0.314354
# 0.321130
# 0.323891
# 0.328486
# 0.328781
# 0.334500
# 0.338656
# 0.344893
# 0.347458
# 0.350352
# 0.351458
# 0.355565
# 0.357270
# 0.363188
# 0.366705
# 0.369545
# 0.371359
# 0.374384
# 0.378778
# 0.383102
# 0.385895
# 0.388062
# 0.389705
# 0.389904
# 0.392658
# 0.394333
# 0.396781
# 0.397980
# 0.400858
# 0.403030
# 0.404643
# 0.405562
# 0.406200
# 0.407440
# 0.408048
# 0.411537
# 0.412496
# 0.413446
# 0.414504
# 0.415819
# 0.418182
# 0.418624
# 0.420086
# 0.420962
# 0.423300
# 0.424828
# 0.427017
# 0.427347
# 0.428506
# 0.429176
# 0.429790
# 0.430453
# 0.431078
# 0.433078
# 0.433578
# 0.434989
# 0.435408
# 0.435998
# 0.436965
# 0.437502
# 0.438386
# 0.438917
# 0.439860
# 0.440453
# 0.440903
# 0.442092
# 0.442602
# 0.442978
# 0.444101
# 0.445441
# 0.445816
# 0.446626
# 0.447967
# 0.448344
# 0.448730
# 0.450147
# 0.450623
# 0.450881
# 0.451247
# 0.451804
# 0.452514
# 0.453862
# 0.453986
# 0.454386
# 0.455190
# 0.455322
# 0.455529
# 0.456386
# 0.456915
# 0.457616
# 0.458041
# 0.459006
# 0.459128
# 0.459711
# 0.460132
# 0.460678
# 0.460888
# 0.461178
# 0.461699
# 0.462226
# 0.462460
# 0.463052
# 0.463401
# 0.464206
# 0.464548
# 0.465013
# 0.465299
# 0.465751
# 0.466226
# 0.467028
# 0.467411
# 0.467856
# 0.468214
# 0.468319
# 0.468814
# 0.469130
# 0.469324
# 0.469536
# 0.469748
# 0.470365
# 0.470881
# 0.471115
# 0.471319
# 0.471778
# 0.472040
# 0.472162
# 0.472907
# 0.473001
# 0.473274
# 0.473363
# 0.473663
# 0.474417
# 0.474772
# 0.475078
# 0.475412
# 0.475774
# 0.475848
# 0.476078
# 0.476250
# 0.476708
# 0.476760
# 0.477357
# 0.477356
# 0.477869
# 0.478370
# 0.478472
# 0.478585
# 0.478807
# 0.479080
# 0.479493
# 0.479604
# 0.479976
# 0.480321
# 0.480495
# 0.480495
# 0.480774
# 0.481137
# 0.481189
# 0.481602
# 0.481729
# 0.482068
# 0.482164
# 0.482527
# 0.482707
# 0.482788
# 0.483177
# 0.483497
# 0.483670
# 0.483845
# 0.484055
# 0.484225
# 0.484302
# 0.484611
# 0.484736
# 0.484819
# 0.485179
# 0.485355
# 0.485594
# 0.485678
# 0.485873
# 0.486124
# 0.486551
# 0.486598
# 0.486744
# 0.486842
# 0.487256
# 0.487403
# 0.487386
# 0.487506
# 0.487737
# 0.487823
# 0.488072
# 0.488301
# 0.488344
# 0.488600
# 0.488868
# 0.488944
# 0.489189
# 0.489491
# 0.489586
# 0.489619
# 0.489846
# 0.489970
# 0.490156
# 0.490313
# 0.490545
# 0.490660
# 0.490776
# 0.490864
# 0.491056
# 0.491188
# 0.491283
# 0.491374
# 0.491590
# 0.491665
# 0.491768
# 0.491935
# 0.492050
# 0.492141
# 0.492291
# 0.492434
# 0.492600
# 0.492783
# 0.492969
# 0.493074
# 0.493239
# 0.493338
# 0.493422
# 0.493685
# 0.493731
# 0.493869
# 0.493975
# 0.493988
# 0.494151
# 0.494371
# 0.494532
# 0.494695
# 0.494815
# 0.494862
# 0.494982
# 0.495039
# 0.495201
# 0.495382
# 0.495535
# 0.495634
# 0.495725
# 0.495797
# 0.496000
# 0.496065
# 0.496260
# 0.496279
# 0.496432
# 0.496539
# 0.496718
# 0.496778
# 0.497035
# 0.497142
# 0.497248
# 0.497304
# 0.497379
# 0.497410
# 0.497585
# 0.497631
# 0.497708
# 0.497829
# 0.497863
# 0.497944
# 0.498009
# 0.498176
# 0.498220
# 0.498351
# 0.498394
# 0.498444
# 0.498631
# 0.498777
# 0.498833
# 0.498848
# 0.498958
# 0.499146
# 0.499202
# 0.499273
# 0.499406
# 0.499463
# 0.499573
# 0.499659
# 0.499731
# 0.499741
# 0.499885
# 0.499933
# 0.499980
# 0.500115
# 0.500218
# 0.500316
# 0.500333
# 0.500429
# 0.500545
# 0.500604
# 0.500704
# 0.500801
# 0.500843
# 0.500906
# 0.501067
# 0.501112
# 0.501243
# 0.501341
# 0.501417
# 0.501508
# 0.501559
# 0.501639
# 0.501746
# 0.501818
# 0.501853
# 0.501954
# 0.502037
# 0.502057
# 0.502201
# 0.502255
# 0.502284
# 0.502450
# 0.502506
# 0.502531
# 0.502596
# 0.502729
# 0.502791
# 0.502849
# 0.502923
# 0.503051
# 0.503115
# 0.503148
# 0.503165
# 0.503329
# 0.503357
# 0.503386
# 0.503491
# 0.503549
# 0.503665
# 0.503673
# 0.503740
# 0.503867
# 0.503940
# 0.503963
# 0.504028
# 0.504118
# 0.504168
# 0.504247
# 0.504342
# 0.504390
# 0.504409
# 0.504456
# 0.504523
# 0.504608
# 0.504696
# 0.504741
# 0.504764
# 0.504839
# 0.504882
# 0.504928
# 0.504987
# 0.505070
# 0.505100
# 0.505138
# 0.505183
# 0.505243
# 0.505321
# 0.505465
# 0.505487
# 0.505505
# 0.505646
# 0.505712
# 0.505729
# 0.505749
# 0.505828
# 0.505856
# 0.505921
# 0.505944
# 0.505998
# 0.506008
# 0.506106
# 0.506228
# 0.506270
# 0.506305
# 0.506400
# 0.506469
# 0.506474
# 0.506495
# 0.506499
# 0.506547
# 0.506649
# 0.506683
# 0.506705
# 0.506751
# 0.506843
# 0.506848
# 0.506885
# 0.506962
# 0.507015
# 0.507079
# 0.507145
# 0.507167
# 0.507199
# 0.507245
# 0.507280
# 0.507339
# 0.507360
# 0.507435
# 0.507505
# 0.507541
# 0.507582
# 0.507576
# 0.507647
# 0.507707
# 0.507771
# 0.507805
# 0.507821
# 0.507862
# 0.507889
# 0.507946
# 0.507996
# 0.508060
# 0.508132
# 0.508164
# 0.508230
# 0.508271
# 0.508318
# 0.508334
# 0.508372
# 0.508413
# 0.508464
# 0.508493
# 0.508557
# 0.508610
# 0.508639
# 0.508663
# 0.508698
# 0.508750
# 0.508797
# 0.508873
# 0.508902
# 0.508920
# 0.508952
# 0.508978
# 0.509001
# 0.509045
# 0.509117
# 0.509164
# 0.509179
# 0.509226
# 0.509253
# 0.509328
# 0.509362
# 0.509357
# 0.509394
# 0.509450
# 0.509505
# 0.509539
# 0.509563
# 0.509575
# 0.509612
# 0.509640
# 0.509681
# 0.509768
# 0.509780
# 0.509822
# 0.509820
# 0.509861
# 0.509910
# 0.509928
# 0.509969
# 0.509969
# 0.510050
# 0.510080
# 0.510109
# 0.510148
# 0.510191
# 0.510193
# 0.510249
# 0.510286
# 0.510295
# 0.510329
# 0.510354
# 0.510413
# 0.510456
# 0.510506
# 0.510536
# 0.510522
# 0.510580
# 0.510631
# 0.510653
# 0.510654
# 0.510685
# 0.510733
# 0.510784
# 0.510756
# 0.510799
# 0.510815
# 0.510850
# 0.510887
# 0.510900
# 0.510889
# 0.510918
# 0.510986
# 0.511000
# 0.511030
# 0.511018
# 0.511083
# 0.511122
# 0.511155
# 0.511177
# 0.511197
# 0.511272
# 0.511296
# 0.511300
# 0.511369
# 0.511394
# 0.511414
# 0.511436
# 0.511465
# 0.511501
# 0.511511
# 0.511534
# 0.511550
# 0.511551
# 0.511616
# 0.511601
# 0.511634
# 0.511644
# 0.511678
# 0.511743
# 0.511766
# 0.511789
# 0.511830
# 0.511853
# 0.511864
# 0.511912
# 0.511951
# 0.511969
# 0.512007
# 0.512024
# 0.512033
# 0.512048
# 0.512064
# 0.512130
# 0.512129
# 0.512181
# 0.512175
# 0.512212
# 0.512198
# 0.512259
# 0.512282
# 0.512298
# 0.512312
# 0.512390
# 0.512400
# 0.512425
# 0.512416
# 0.512443
# 0.512417
# 0.512525
# 0.512518
# 0.512542
# 0.512561
# 0.512559
# 0.512607
# 0.512596
# 0.512650
# 0.512656
# 0.512695
# 0.512686
# 0.512723
# 0.512750
# 0.512737
# 0.512799
# 0.512827
# 0.512825
# 0.512874
# 0.512880
# 0.512889
# 0.512913
# 0.512937
# 0.512921
# 0.512955
# 0.512973
# 0.513012
# 0.513047
# 0.513080
# 0.513086
# 0.513104
# 0.513124
# 0.513121
# 0.513148
# 0.513171
# 0.513200
# 0.513212
# 0.513201
# 0.513260
# 0.513260
# 0.513268
# 0.513300
# 0.513325
# 0.513349
# 0.513342
# 0.513376
# 0.513405
# 0.513432
# 0.513429
# 0.513484
# 0.513492
# 0.513503
# 0.513511
# 0.513512
# 0.513555
# 0.513591
# 0.513604
# 0.513626
# 0.513638
# 0.513654
# 0.513668
# 0.513685
# 0.513700
# 0.513711
# 0.513746
# 0.513760
# 0.513773
# 0.513779
# 0.513805
# 0.513811
# 0.513860
# 0.513839
# 0.513888
# 0.513915
# 0.513936
# 0.513957
# 0.513965
# 0.513975
# 0.513997
# 0.514020
# 0.514032
# 0.514040
# 0.514044
# 0.514071
# 0.514077
# 0.514101
# 0.514138
# 0.514130
# 0.514118
# 0.514168
# 0.514166
# 0.514187
# 0.514171
# 0.514219
# 0.514247
# 0.514255
# 0.514249
# 0.514294
# 0.514305
# 0.514345
# 0.514362
# 0.514367
# 0.514365
# 0.514399
# 0.514412
# 0.514428
# 0.514451
# 0.514460
# 0.514448
# 0.514497
# 0.514513
# 0.514531
# 0.514553
# 0.514550
# 0.514577
# 0.514600
# 0.514610
# 0.514614
# 0.514632
# 0.514653
# 0.514653
# 0.514664
# 0.514683
# 0.514691
# 0.514695
# 0.514713
# 0.514728
# 0.514765
# 0.514735
# 0.514765
# 0.514802
# 0.514816
# 0.514831
# 0.514841
# 0.514840
# 0.514867
# 0.514886
# 0.514896
# 0.514888
# 0.514878
# 0.514935
# 0.514943
# 0.514980
# 0.514981
# 0.515001
# 0.515018
# 0.515007
# 0.515014
# 0.515011
# 0.515042
# 0.515021
# 0.515067
# 0.515083
# 0.515100
# 0.515130
# 0.515142
# 0.515153
# 0.515158
# 0.515162
# 0.515178
# 0.515176
# 0.515182
# 0.515217
# 0.515237
# 0.515250
# 0.515256
# 0.515248
# 0.515267
# 0.515278
# 0.515301
# 0.515296
# 0.515328
# 0.515335
# 0.515349
# 0.515365
# 0.515369
# 0.515396
# 0.515378
# 0.515424
# 0.515429
# 0.515425
# 0.515450
# 0.515467
# 0.515453
# 0.515481
# 0.515502
# 0.515493
# 0.515524
# 0.515536
# 0.515540
# 0.515532
# 0.515541
# 0.515560
# 0.515585
# 0.515602
# 0.515604
# 0.515587
# 0.515622
# 0.515624
# 0.515650
# 0.515651
# 0.515646
# 0.515636
# 0.515704
# 0.515707
# 0.515716
# 0.515700
# 0.515704
# 0.515742
# 0.515744
# 0.515734
# 0.515785
# 0.515792
# 0.515791
# 0.515778
# 0.515794
# 0.515833
# 0.515834
# 0.515847
# 0.515875
# 0.515882
# 0.515893
# 0.515896
# 0.515899
# 0.515931
# 0.515926
# 0.515945
# 0.515917
# 0.515940
# 0.515974
# 0.515981
# 0.515965
# 0.515999
# 0.516005
# 0.516014
# 0.516020
# 0.516016
# 0.515997
# 0.516048
# 0.516076
# 0.516044
# 0.516092
# 0.516098
# 0.516098
# 0.516093
# 0.516088
# 0.516117
# 0.516100
# 0.516106
# 0.516129
# 0.516147
# 0.516153
# 0.516177
# 0.516170
# 0.516192
# 0.516209
# 0.516139
# 0.516214
# 0.516211
# 0.516239
# 0.516221
# 0.516260
# 0.516255
# 0.516283
# 0.516292
# 0.516266
# 0.516284
# 0.516310
# 0.516321
# 0.516301
# 0.516321
# 0.516337
# 0.516317
# 0.516307
# 0.516367
# 0.516336
# 0.516373
# 0.516397
# 0.516403
# 0.516374
# 0.516398
# 0.516429
# 0.516410
# 0.516442
# 0.516448
# 0.516472
# 0.516483
# 0.516483
# 0.516485
# 0.516489
# 0.516507
# 0.516524
# 0.516504
# 0.516501
# 0.516525
# 0.516555
# 0.516546
# 0.516533
# 0.516527
# 0.516567
# 0.516602
# 0.516603
# 0.516585
# 0.516617
# 0.516625
# 0.516621
# 0.516639
# 0.516602
# 0.516652
# 0.516664
# 0.516567
# 0.516660
# 0.516675
# 0.516665
# 0.516671
# 0.516705
# 0.516702
# 0.516711
# 0.516712
# 0.516709
# 0.516747
# 0.516737
# 0.516759
# 0.516761
# 0.516772
# 0.516770
# 0.516788
# 0.516804
# 0.516796
# 0.516796
# 0.516770
# 0.516820
# 0.516829
# 0.516827
# 0.516832
# 0.516846
# 0.516858
# 0.516868
# 0.516856
# 0.516880
# 0.516866
# 0.516876
# 0.516886
# 0.516894
# 0.516910
# 0.516912
# 0.516918
# 0.516932
# 0.516928
# 0.516937
# 0.516926
# 0.516944
# 0.516953
# 0.516966
# 0.516951
# 0.516947
# 0.516983
# 0.516990
# 0.517003
# 0.517014
# 0.516989
# 0.516987
# 0.517014
# 0.517029
# 0.517035
# 0.517026
# 0.517020
# 0.517052
# 0.517055
# 0.517063
# 0.517069
# 0.517074
# 0.517088
# 0.517070
# 0.517082
# 0.517096
# 0.517087
# 0.517104
# 0.517105
# 0.517120
# 0.517133
# 0.517135
# 0.517145
# 0.517146
# 0.517145
# 0.517156
# 0.517091
# 0.517171
# 0.517184
# 0.517129
# 0.517196
# 0.517197
# 0.517202
# 0.517205
# 0.517196
# 0.517200
# 0.517219
# 0.517235
# 0.517245
# 0.517228
# 0.517253
# 0.517233
# 0.517259
# 0.517263
# 0.517262
# 0.517254
# 0.517269
# 0.517286
# 0.517285
# 0.517287
# 0.517306
# 0.517315
# 0.517315
# 0.517302
# 0.517303
# 0.517313
# 0.517298
# 0.517336
# 0.517300
# 0.517355
# 0.517360
# 0.517359
# 0.517337
# 0.517379
# 0.517380
# 0.517389
# 0.517383
# 0.517394
# 0.517405
# 0.517411
# 0.517397
# 0.517388
# 0.517396
# 0.517394
# 0.517447
# 0.517388
# 0.517450
# 0.517437
# 0.517453
# 0.517430
# 0.517461
# 0.517448
# 0.517476
# 0.517475
# 0.517471
# 0.517477
# 0.517489
# 0.517506
# 0.517470
# 0.517502
# 0.517508
# 0.517511
# 0.517488
# 0.517515
# 0.517508
# 0.517497
# 0.517549
# 0.517547
# 0.517558
# 0.517562
# 0.517562
# 0.517572
# 0.517546
# 0.517546
# 0.517577
# 0.517579
# 0.517585
# 0.517571
# 0.517602
# 0.517610
# 0.517612
# 0.517566
# 0.517620
# 0.517627
# 0.517605
# 0.517633
# 0.517627
# 0.517646
# 0.517635
# 0.517609
# 0.517651
# 0.517647
# 0.517605
# 0.517642
# 0.517665
# 0.517668
# 0.517678
# 0.517680
# 0.517667
# 0.517686
# 0.517657
# 0.517643
# 0.517645
# 0.517672
# 0.517707
# 0.517683
# 0.517707
# 0.517682
# 0.517706
# 0.517717
# 0.517696
# 0.517708
# 0.517735
# 0.517714
# 0.517721
# 0.517758
# 0.517721
# 0.517764
# 0.517768
# 0.517762
# 0.517785
# 0.517778
# 0.517769
# 0.517798
# 0.517786
# 0.517795
# 0.517805
# 0.517785
# 0.517816
# 0.517815
# 0.517808
# 0.517826
# 0.517812
# 0.517829
# 0.517804
# 0.517826
# 0.517843
# 0.517825
# 0.517849
# 0.517818
# 0.517819
# 0.517866
# 0.517863
# 0.517835
# 0.517869
# 0.517869
# 0.517843
# 0.517880
# 0.517885
# 0.517867
# 0.517878
# 0.517892
# 0.517875
# 0.517911
# 0.517909
# 0.517906
# 0.517900
# 0.517931
# 0.517925
# 0.517895
# 0.517935
# 0.517928
# 0.517943
# 0.517949
# 0.517937
# 0.517942
# 0.517936
# 0.517937
# 0.517947
# 0.517966
# 0.517930
# 0.517916
# 0.517981
# 0.517946
# 0.517979
# 0.517994
# 0.517967
# 0.517970
# 0.517987
# 0.517991
# 0.517993
# 0.518003
# 0.518009
# 0.517999
# 0.517959
# 0.517975
# 0.518024
# 0.518017
# 0.517998
# 0.518027
# 0.518036
# 0.518032
# 0.518030
# 0.518039
# 0.518029
# 0.518043
# 0.518058
# 0.518028
# 0.518068
# 0.518054
# 0.518063
# 0.518035
# 0.518068
# 0.518054
# 0.518083
# 0.518074
# 0.518069
# 0.518101
# 0.518092
# 0.518090
# 0.518070
# 0.518075
# 0.518090
# 0.518096
# 0.518089
# 0.518107
# 0.518116
# 0.518127
# 0.518073
# 0.518119
# 0.518098
# 0.518121
# 0.518132
# 0.518134
# 0.518115
# 0.518138
# 0.518142
# 0.518142
# 0.518098
# 0.518123
# 0.518137
# 0.518145
# 0.518162
# 0.518104
# 0.518173
# 0.518168
# 0.518161
# 0.518155
# 0.518183
# 0.518190
# 0.518160
# 0.518180
# 0.518190
# 0.518173
# 0.518183
# 0.518191
# 0.518192
# 0.518202
# 0.518209
# 0.518203
# 0.518206
# 0.518212
# 0.518217
# 0.518216
# 0.518206
# 0.518210
# 0.518219
# 0.518223
# 0.518224
# 0.518231
# 0.518221
# 0.518252
# 0.518243
# 0.518244
# 0.518249
# 0.518254
# 0.518217
# 0.518226
# 0.518224
# 0.518260
# 0.518260
# 0.518264
# 0.518259
# 0.518249
# 0.518262
# 0.518269
# 0.518276
# 0.518270
# 0.518246
# 0.518265
# 0.518281
# 0.518288
# 0.518258
# 0.518273
# 0.518309
# 0.518299
# 0.518250
# 0.518264
# 0.518313
# 0.518287
# 0.518303
# 0.518294
# 0.518326
# 0.518286
# 0.518296
# 0.518290
# 0.518323
# 0.518331
# 0.518326
# 0.518319
# 0.518312
# 0.518323
# 0.518336
# 0.518310
# 0.518348
# 0.518352
# 0.518331
# 0.518335
# 0.518346
# 0.518348
# 0.518335
# 0.518354
# 0.518347
# 0.518361
# 0.518352
# 0.518358
# 0.518370
# 0.518366
# 0.518362
# 0.518368
# 0.518338
# 0.518382
# 0.518383
# 0.518364
# 0.518385
# 0.518367
# 0.518383
# 0.518383
# 0.518382
# 0.518385
# 0.518406
# 0.518393
# 0.518395
# 0.518416
# 0.518409
# 0.518385
# 0.518407
# 0.518412
# 0.518383
# 0.518413
# 0.518419
# 0.518411
# 0.518420
# 0.518421
# 0.518437
# 0.518346
# 0.518434
# 0.518410
# 0.518435
# 0.518429
# 0.518416
# 0.518437
# 0.518370
# 0.518445
# 0.518426
# 0.518448
# 0.518445
# 0.518464
# 0.518460
# 0.518461
# 0.518424
# 0.518455
# 0.518456
# 0.518448
# 0.518454
# 0.518460
# 0.518461
# 0.518483
# 0.518479
# 0.518461
# 0.518487
# 0.518480
# 0.518485
# 0.518490
# 0.518488
# 0.518497
# 0.518480
# 0.518483
# 0.518486
# 0.518502
# 0.518495
# 0.518477
# 0.518501
# 0.518514
# 0.518483
# 0.518510
# 0.518501
# 0.518473
# 0.518468
# 0.518503
# 0.518485
# 0.518520
# 0.518505
# 0.518509
# 0.518521
# 0.518509
# 0.518490
# 0.518507
# 0.518504
# 0.518522
# 0.518515
# 0.518512
# 0.518523
# 0.518550
# 0.518532
# 0.518508
# 0.518550
# 0.518554
# 0.518544
# 0.518519
# 0.518514
# 0.518533
# 0.518554
# 0.518554
# 0.518549
# 0.518539
# 0.518554
# 0.518531
# 0.518550
# 0.518552
# 0.518571
# 0.518560
# 0.518569
# 0.518577
# 0.518539
# 0.518533
# 0.518568
# 0.518584
# 0.518585
# 0.518587
# 0.518584
# 0.518567
# 0.518569
# 0.518593
# 0.518575
# 0.518573
# 0.518573
# 0.518597
# 0.518584
# 0.518596
# 0.518594
# 0.518576
# 0.518581
# 0.518600
# 0.518571
# 0.518597
# 0.518596
# 0.518591
# 0.518605
# 0.518611
# 0.518614
# 0.518606
# 0.518616
# 0.518605
# 0.518622
# 0.518614
# 0.518594
# 0.518624
# 0.518576
# 0.518622
# 0.518597
# 0.518624
# 0.518637
# 0.518639
# 0.518634
# 0.518598
# 0.518611
# 0.518628
# 0.518620
# 0.518595
# 0.518632
# 0.518624
# 0.518641
# 0.518624
# 0.518645
# 0.518643
# 0.518626
# 0.518600
# 0.518620
# 0.518642
# 0.518629
# 0.518659
# 0.518651
# 0.518665
# 0.518659
# 0.518638
# 0.518662
# 0.518664
# 0.518640
# 0.518642
# 0.518674
# 0.518652
# 0.518625
# 0.518670
# 0.518669
# 0.518653
# 0.518677
# 0.518679
# 0.518667
# 0.518654
# 0.518689
# 0.518658
# 0.518662
# 0.518665
# 0.518673
# 0.518690
# 0.518697
# 0.518687
# 0.518696
# 0.518695
# 0.518704
# 0.518682
# 0.518700
# 0.518707
# 0.518699
# 0.518674
# 0.518693
# 0.518697
# 0.518696
# 0.518716
# 0.518722
# 0.518720
# 0.518696
# 0.518720
# 0.518706
# 0.518713
# 0.518702
# 0.518695
# 0.518725
# 0.518721
# 0.518699
# 0.518705
# 0.518707
# 0.518731
# 0.518723
# 0.518727
# 0.518728
# 0.518719
# 0.518694
# 0.518718
# 0.518759
# 0.518826
# 0.518843
# 0.518832
# 0.518853
# 0.518854
# 0.518853
# 0.518826
# 0.518750
# 0.518849
# 0.518835
# 0.518828
# 0.518812
# 0.518831
# 0.518826
# 0.518845
# 0.518786
# 0.518833
# 0.518755
# 0.518841
# 0.518815
# 0.518857
# 0.518830
# 0.518853
# 0.518839
# 0.518830
# 0.518851
# 0.518834
# 0.518832
# 0.518843
# 0.518847
# 0.518831
# 0.518843
# 0.518799
# 0.518822
# 0.518854
# 0.518817
# 0.518826
# 0.518855
# 0.518851
# 0.518811
# 0.518840
# 0.518834
# 0.518811
# 0.518853
# 0.518838
# 0.518851
# 0.518840
# 0.518843
# 0.518835
# 0.518822
# 0.518829
# 0.518843
# 0.518844
# 0.518833
# 0.518846
# 0.518843
# 0.518838
# 0.518855
# 0.518844
# 0.518832
# 0.518847
# 0.518842
# 0.518852
# 0.518848
# 0.518828
# 0.518827
# 0.518839
# 0.518852
# 0.518837
# 0.518856
# 0.518851
# 0.518858
# 0.518824
# 0.518842
# 0.518814
# 0.518857
# 0.518850
# 0.518859
# 0.518825
# 0.518851
# 0.518841
# 0.518820
# 0.518841
# 0.518826
# 0.518855
# 0.518855
# 0.518841
# 0.518807
# 0.518857
# 0.518840
# 0.518836
# 0.518831
# 0.518784
# 0.518831
# 0.518809
# 0.518853
# 0.518846
# 0.518847
# 0.518851
# 0.518852
# 0.518842
# 0.518825
# 0.518847
# 0.518821
# 0.518847
# 0.518835
# 0.518837
# 0.518849
# 0.518850
# 0.518842
# 0.518829
# 0.518850
# 0.518819
# 0.518822
# 0.518844
# 0.518837
# 0.518849
# 0.518821
# 0.518852
# 0.518832
# 0.518757
# 0.518815
# 0.518843
# 0.518859
# 0.518835
# 0.518858
# 0.518838
# 0.518833
# 0.518845
# 0.518834
# 0.518843
# 0.518843
# 0.518841
# 0.518809
# 0.518800
# 0.518841
# 0.518839
# 0.518828
# 0.518833
# 0.518853
# 0.518816
# 0.518833
# 0.518854
# 0.518842
# 0.518836
# 0.518834
# 0.518845
# 0.518821
# 0.518843
# 0.518843
# 0.518841
# 0.518843
# 0.518854
# 0.518853
# 0.518842
# 0.518850
# 0.518800
# 0.518850
# 0.518848
# 0.518854
# 0.518855
# 0.518850
# 0.518811
# 0.518846
# 0.518840
# 0.518844
# 0.518848
# 0.518822
# 0.518821
# 0.518846
# 0.518800
# 0.518845
# 0.518825
# 0.518842
# 0.518836
# 0.518836
# 0.518780
# 0.518846
# 0.518833
# 0.518850
# 0.518854
# 0.518846
# 0.518815
# 0.518843
# 0.518854
# 0.518763
# 0.518833
# 0.518842
# 0.518816
# 0.518859
# 0.518842
# 0.518843
# 0.518840
# 0.518858
# 0.518857
# 0.518834
# 0.518851
# 0.518847
# 0.518852
# 0.518838
# 0.518848
# 0.518845
# 0.518844
# 0.518851
# 0.518834
# 0.518822
# 0.518833
# 0.518839
# 0.518850
# 0.518853
# 0.518856
# 0.518833
# 0.518849
# 0.518849
# 0.518848
# 0.518843
# 0.518843
# 0.518831
# 0.518847
# 0.518826
# 0.518846
# 0.518832
# 0.518801
# 0.518840
# 0.518846
# 0.518836
# 0.518855
# 0.518846
# 0.518817
# 0.518847
# 0.518837
# 0.518840
# 0.518819
# 0.518851
# 0.518814
# 0.518844
# 0.518848
# 0.518832
# 0.518834
# 0.518848
# 0.518834
# 0.518852
# 0.518833
# 0.518833
# 0.518847
# 0.518847
# 0.518821
# 0.518846
# 0.518836
# 0.518837
# 0.518836
# 0.518845
# 0.518837
# 0.518852
# 0.518841
# 0.518834
# 0.518824
# 0.518846
# 0.518843
# 0.518818
# 0.518840
# 0.518807
# 0.518830
# 0.518839
# 0.518847
# 0.518844
# 0.518839
# 0.518834
# 0.518824
# 0.518849
# 0.518834
# 0.518812
# 0.518839
# 0.518848
# 0.518839
# 0.518834
# 0.518846
# 0.518822
# 0.518836
# 0.518856
# 0.518849
# 0.518846
# 0.518855
# 0.518852
# 0.518840
# 0.518836
# 0.518826
# 0.518837
# 0.518808
# 0.518830
# 0.518850
# 0.518845
# 0.518851
# 0.518851
# 0.518857
# 0.518851
# 0.518856
# 0.518829
# 0.518856
# 0.518850
# 0.518838
# 0.518810
# 0.518804
# 0.518847
# 0.518845
# 0.518849
# 0.518850
# 0.518851
# 0.518770
# 0.518845
# 0.518825
# 0.518841
# 0.518782
# 0.518850
# 0.518848
# 0.518838
# 0.518844
# 0.518850
# 0.518839
# 0.518818
# 0.518819
# 0.518817
# 0.518838
# 0.518828
# 0.518828
# 0.518826
# 0.518839
# 0.518832
# 0.518843
# 0.518829
# 0.518807
# 0.518835
# 0.518855
# 0.518848
# 0.518846
# 0.518823
# 0.518846
# 0.518844
# 0.518842
# 0.518816
# 0.518852
# 0.518842
# 0.518837
# 0.518835
# 0.518827
# 0.518808
# 0.518838
# 0.518794
# 0.518844
# 0.518847
# 0.518825
# 0.518854
# 0.518836
# 0.518850
# 0.518845
# 0.518841
# 0.518782
# 0.518848
# 0.518850
# 0.518838
# 0.518840
# 0.518848
# 0.518849
# 0.518852
# 0.518833
# 0.518843
# 0.518827
# 0.518827
# 0.518819
# 0.518849
# 0.518838
# 0.518826
# 0.518841
# 0.518851
# 0.518855
# 0.518835
# 0.518800
# 0.518841
# 0.518858
# 0.518850
# 0.518838
# 0.518844
# 0.518849
# 0.518838
# 0.518850
# 0.518846
# 0.518848
# 0.518850
# 0.518829
# 0.518856
# 0.518839
# 0.518852
# 0.518831
# 0.518844
# 0.518847
# 0.518847
# 0.518840
# 0.518833
# 0.518832
# 0.518850
# 0.518836
# 0.518832
# 0.518832
# 0.518836
# 0.518840
# 0.518811
# 0.518820
# 0.518825
# 0.518840
# 0.518817
# 0.518832
# 0.518776
# 0.518834
# 0.518839
# 0.518827
# 0.518835
# 0.518830
# 0.518843
# 0.518830
# 0.518824
# 0.518850
# 0.518846
# 0.518833
# 0.518835
# 0.518832
# 0.518819
# 0.518840
# 0.518841
# 0.518858
# 0.518841
# 0.518827
# 0.518849
# 0.518857
# 0.518840
# 0.518846
# 0.518816
# 0.518826
# 0.518811
# 0.518849
# 0.518831
# 0.518825
# 0.518851
# 0.518819
# 0.518847
# 0.518823
# 0.518824
# 0.518849
# 0.518774
# 0.518828
# 0.518853
# 0.518844
# 0.518849
# 0.518817
# 0.518816
# 0.518838
# 0.518849
# 0.518849
# 0.518822
# 0.518846
# 0.518837
# 0.518851
# 0.518848
# 0.518842
# 0.518844
# 0.518829
# 0.518848
# 0.518833
# 0.518806
# 0.518832
# 0.518849
# 0.518839
# 0.518837
# 0.518840
# 0.518856
# 0.518851
# 0.518856
# 0.518849
# 0.518845
# 0.518849
# 0.518837
# 0.518846
# 0.518841
# 0.518846
# 0.518846
# 0.518846
# 0.518845
# 0.518830
# 0.518843
# 0.518851

# %%
limit = np.load("limit.npy")

# %%
l.shape
# Out:
# (2000,)

# %%
result = pd.read_csv("limitTemp_sat.csv", header=None)

# %%
result.shape[0]
# Out:
# 141

# %%
result
# Out:
#           0           1           2           3          4          5      \
# 0    296.664705  287.832584  142.288438  139.567812  78.088094  77.483258
# 1    294.166047  290.466372  142.248632  139.939101  78.527027  76.355189
# 2    292.660334  291.928162  144.294377  137.935038  78.410441  77.062274
# 3    301.697323  282.974790  141.440911  140.870948  77.740926  76.759670
# 4    298.882496  285.558326  142.449980  139.672385  79.158038  76.219813
# ..          ...         ...         ...         ...        ...        ...
# 136  299.990109  284.498040  143.127272  139.009193  78.984268  76.164044
# 137  295.406615  289.751641  144.785361  136.543918  79.338580  75.819234
# 138  295.967576  288.463789  143.426674  138.430404  78.386937  76.341398
# 139  298.167306  286.573298  143.322915  138.648306  78.025303  77.040845
# 140  295.945848  289.118506  142.577770  139.725130  78.656667  75.884010
#
#          6          7          8          9      ...         10502  \
# 0    64.708525  62.544155  61.806616  60.637433  ... -7.192547e-15
# 1    65.008875  64.048027  61.737083  58.859806  ... -7.117739e-15
# 2    63.840711  62.837632  61.301065  61.196068  ... -7.270502e-15
# 3    64.986200  63.397551  62.412103  58.875047  ... -7.226109e-15
# 4    63.575604  63.496865  62.154323  60.344694  ... -7.411842e-15
# ..         ...        ...        ...        ...  ...           ...
# 136  64.615217  63.355589  61.575155  60.431857  ... -7.180987e-15
# 137  64.982155  63.579136  61.876858  59.328644  ... -7.453994e-15
# 138  64.793472  62.646928  62.011448  60.342353  ... -7.352379e-15
# 139  64.819083  63.766968  60.690450  60.424742  ... -7.062153e-15
# 140  64.431841  63.144296  62.152286  59.774917  ... -7.140717e-15
#
#             10503         10504         10505         10506         10507  \
# 0   -7.491634e-15 -7.491634e-15 -8.133343e-15 -8.133343e-15 -8.674336e-15
# 1   -7.150851e-15 -7.150851e-15 -7.349323e-15 -7.349323e-15 -7.755031e-15
# 2   -7.351398e-15 -7.351398e-15 -7.898357e-15 -7.898357e-15 -8.408286e-15
# 3   -7.226109e-15 -7.458789e-15 -8.064397e-15 -8.064397e-15 -1.066540e-14
# 4   -7.411842e-15 -7.714167e-15 -7.714167e-15 -8.490333e-15 -8.725034e-15
# ..            ...           ...           ...           ...           ...
# 136 -7.180987e-15 -7.258230e-15 -7.556901e-15 -7.556901e-15 -8.094959e-15
# 137 -7.634056e-15 -7.634056e-15 -7.835373e-15 -7.835373e-15 -8.770826e-15
# 138 -7.446160e-15 -7.921612e-15 -7.921612e-15 -8.335324e-15 -8.335324e-15
# 139 -7.170505e-15 -7.221975e-15 -7.221975e-15 -7.824251e-15 -7.824251e-15
# 140 -7.140717e-15 -7.166609e-15 -7.399773e-15 -7.399773e-15 -8.062354e-15
#
#             10508         10509         10510         10511
# 0   -1.067499e-14 -1.272100e-14 -1.272100e-14 -1.360260e-14
# 1   -8.617684e-15 -8.617684e-15 -1.248835e-14 -1.248835e-14
# 2   -8.605321e-15 -1.696933e-14 -1.696933e-14 -2.031696e-14
# 3   -1.066540e-14 -1.100563e-14 -1.612762e-14 -1.612762e-14
# 4   -8.725034e-15 -1.074620e-14 -1.074620e-14 -1.315635e-14
# ..            ...           ...           ...           ...
# 136 -8.094959e-15 -1.124137e-14 -1.258163e-14 -1.258163e-14
# 137 -9.727780e-15 -9.727780e-15 -1.257819e-14 -1.257819e-14
# 138 -8.659648e-15 -8.659648e-15 -1.203804e-14 -1.761986e-14
# 139 -8.980298e-15 -8.980298e-15 -1.199299e-14 -1.199299e-14
# 140 -8.062354e-15 -9.591322e-15 -9.591322e-15 -1.179682e-14
#
# [141 rows x 10512 columns]

# %%
M = result.shape[1]
limit = np.zeros(M)
for i in range(M):
    limit[i] = 1 - norm.cdf((eigenValues[i] - result.iloc[:,i].mean())/result.iloc[:,i].std())
    #print("%f"%(1 - norm.cdf((eigenValues[i] - result[:,i].mean())/result[:,i].std())))
    if limit[i] > p_value: break

# %%
d = np.row_stack((a,b,c))

# %%
ts = Surrogates(d)
# Out:
# Generated an instance of the Surrogates class.

# %%
ts.AAFT_surrogates(d)
# Out:
# Generating correlated noise surrogates...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-0e29b96d58a9> in <module>()
# ----> 1 ts.AAFT_surrogates(d)
#
# ~/anaconda3/lib/python3.6/site-packages/pyunicorn/timeseries/surrogates.py in AAFT_surrogates(self, original_data)
#     386         #  Phase randomize rescaled data
#     387         phase_randomized_data = \
# --> 388             self.correlated_noise_surrogates(rescaled_data)
#     389
#     390         #  Rescale back to amplitude distribution of original data
#
# ~/anaconda3/lib/python3.6/site-packages/pyunicorn/timeseries/surrogates.py in correlated_noise_surrogates(self, original_data)
#     339         #  so it is stored in self._original_data_fft.
#     340         if self._fft_cached:
# --> 341             surrogates = self._original_data_fft
#     342         else:
#     343             surrogates = np.fft.rfft(original_data, axis=1)
#
# AttributeError: 'Surrogates' object has no attribute '_original_data_fft'

# %%
# Out:
# Generating correlated noise surrogates...
# array([[ 3.9791028 ,  5.45287519,  5.02532696,  1.94243231,  1.3774935 ,
#          3.02007958,  1.86420421,  3.7646391 ],
#        [ 4.22527408,  2.90988095,  7.94998781,  3.50909721, -2.71409865,
#          4.7119573 ,  4.94455026,  4.76008565],
#        [-3.59516812, -1.97702414, -6.70089651, -6.96161177, -6.30666783,
#         -5.75830119, -4.50530105, -3.28342285]])

# %%
ts.white_noise_surrogates(d)
# Out:
# Generating white noise surrogates by random shuffling...
# array([[ 3,  5,  5,  1,  3,  5,  4,  2],
#        [ 8, 12,  7,  6,  5,  3,  3,  4],
#        [ 2,  7,  6,  7,  5,  4,  6,  3]])

# %%
ts.refined_AAFT_surrogates(d,1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-ecdd0d57b9bc> in <module>()
# ----> 1 ts.refined_AAFT_surrogates(d,1000)
#
# ~/anaconda3/lib/python3.6/site-packages/pyunicorn/timeseries/surrogates.py in refined_AAFT_surrogates(self, original_data, n_iterations, output)
#     426         #  Get Fourier transform of original data with caching
#     427         if self._fft_cached:
# --> 428             fourier_transform = self._original_data_fft
#     429         else:
#     430             fourier_transform = np.fft.rfft(original_data, axis=1)
#
# AttributeError: 'Surrogates' object has no attribute '_original_data_fft'

# %%
N = 10
result = np.zeros((N,3))
for i in range(N):
    ts = Surrogates(d)
    sample = ts.correlated_noise_surrogates(d)
    eigenValues, eigenVectors = np.linalg.eig(np.cov(sample))
    idx = eigenValues.argsort()[::-1]   
    eigenValues = eigenValues[idx]
    result[i,:] = eigenValues
    ts.clear_cache()
# Out:
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...
# Generated an instance of the Surrogates class.
# Generating correlated noise surrogates...

# %%
np.cov(d)
# Out:
# array([[ 2.28571429, -1.28571429,  2.71428571],
#        [-1.28571429,  9.14285714, -1.        ],
#        [ 2.71428571, -1.        ,  3.42857143]])

# %%
d
# Out:
# array([[ 1,  2,  3,  3,  4,  5,  5,  5],
#        [12,  3,  4,  5,  6,  7,  3,  8],
#        [ 2,  3,  4,  5,  6,  7,  6,  7]])

# %%
eigenValues, eigenVectors = np.linalg.eig(np.cov(d))
idx = eigenValues.argsort()[::-1]   
eigenValues = eigenValues[idx]

# %%
result
# Out:
# array([[ 9.90562985,  3.93204551,  0.82269823],
#        [10.91110084,  2.33278413,  1.31345101],
#        [11.46662559,  2.34593331,  0.78591232],
#        [10.25746858,  3.63521738,  0.62321524],
#        [11.58200185,  2.7306186 ,  0.15794229],
#        [ 9.92805697,  3.51538064,  1.12691524],
#        [10.02253596,  3.37299933,  1.38606517],
#        [ 9.21170952,  4.57287297,  0.99065836],
#        [10.01374339,  4.10176874,  0.3919988 ],
#        [10.86831356,  3.15128156,  0.55702729]])

# %%
eigenValues
# Out:
# array([9.76570372, 5.02381354, 0.06762559])
